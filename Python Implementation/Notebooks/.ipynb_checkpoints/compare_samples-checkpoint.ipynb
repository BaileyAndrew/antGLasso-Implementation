# %%
import dependencies
import soft_dependencies
# Out:
# Python Version 3.9.12 (main, Apr  5 2022, 01:53:17)
# [Clang 12.0.0 ]
# Numpy Version 1.21.5
# Scipy Version 1.7.3
# Sklearn Version 1.0.2
# Matplotlib Version 3.5.1
# Pandas Version 1.4.2
# Line Profiler Version 3.3.1
# Memory Profiler Version 0.58.0

# %%
import numpy as np
import matplotlib.pyplot as plt

np.set_printoptions(precision=3, suppress=True)
# %load_ext autoreload
# %autoreload 2

# %%
from Scripts.experiments import create_precision_recall_curves

# %% [markdown]
# # scBiGLasso Easy

# %%
# How does choice of betas and matrix size affect results?
# on 'easy' data
# =================== for scBiGLasso ================
samples = [1, 2, 5, 10, 20, 50, 100]
betas = [
    10**np.arange(-1, 1, 0.1), # 50
    10**np.arange(-1, 1, 0.1),
    10**np.arange(-1, 1, 0.1),
    10**np.arange(-1, 1, 0.1),
    10**np.arange(-1, 1, 0.1),
    10**np.arange(-1, 1, 0.1),
    10**np.arange(-1, 1, 0.1)
]
vary_sizes_experiment = dict({})
for idx, m in enumerate(samples):
    fig, axs, dicts = create_precision_recall_curves(
        betas[idx],
        m,
        50,
        attempts=1, # Too slow for more attempts!
        indices_to_highlight=[],
        alg="scBiGLasso",
        df_scale=2
    )
    fig.savefig(f'../Plots/Vary Samples - scBiGLasso - Easy/Precision-Recall-Vary-Samples-{m}')
    display(fig) # Force figure to display NOW (`fig.show()` does not do this)
    plt.close(fig) # Suppress double-displaying the figure
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <cell line: 15>()
#      14 vary_sizes_experiment = dict({})
#      15 for idx, m in enumerate(samples):
# ---> 16     fig, axs, dicts = create_precision_recall_curves(
#      17         betas[idx],
#      18         m,
#      19         50,
#      20         attempts=10,
#      21         indices_to_highlight=[],
#      22         alg="scBiGLasso",
#      23         df_scale=2
#      24     )
#      25     fig.savefig(f'../Plots/Vary Samples - scBiGLasso - Easy/Precision-Recall-Vary-Samples-{m}')
#      26     display(fig) # Force figure to display NOW (`fig.show()` does not do this)
#
# File ~/Desktop/Python Notebooks.nosync/Research/scBiGLasso Implementation/Python Implementation/Scripts/experiments.py:178, in create_precision_recall_curves(betas_to_try, m, p, indices_to_highlight, attempts, verbose, alg, df_scale, B_approx_iters, cm_mode)
#     175 else:
#     176     raise ValueError(f"no such algorithm {alg}")
# --> 178 Psi_cms, Theta_cms = get_cms_for_betas(
#     179     betas_to_try,
#     180     attempts=attempts,
#     181     kwargs_gen=kwargs_gen,
#     182     kwargs_lasso=kwargs_lasso,
#     183     verbose=verbose,
#     184     alg=alg,
#     185     cm_mode=cm_mode
#     186 )
#     188 return make_cm_plots(
#     189     betas_to_try,
#     190     Psi_cms,
#    (...)
#     193     f"Precision-Recall Plots for {n}x{n} Psi/Theta as L1 Penalty β Varies ({m} samples)"
#     194 )
#
# File ~/Desktop/Python Notebooks.nosync/Research/scBiGLasso Implementation/Python Implementation/Scripts/experiments.py:46, in get_cms_for_betas(betas_to_try, attempts, kwargs_gen, kwargs_lasso, cm_mode, verbose, alg)
#      44 Psi_gen, Theta_gen, Ys = generate_Ys(**kwargs_gen)
#      45 if alg == "scBiGLasso":
# ---> 46     Psi, Theta = scBiGLasso(
#      47         Ys=Ys,
#      48         beta_1=b,
#      49         beta_2=b,
#      50         Psi_init=None,#np.eye(Ys.shape[-1]),
#      51         Theta_init=None,#np.eye(Ys.shape[-1]),
#      52         verbose=verbose,
#      53         **kwargs_lasso
#      54     )
#      55 elif alg == "anBiGLasso":
#      56     Psi, Theta = anBiGLasso(
#      57         Ys=Ys,
#      58         beta_1=b,
#      59         beta_2=b,
#      60         **kwargs_lasso
#      61     )
#
# File ~/Desktop/Python Notebooks.nosync/Research/scBiGLasso Implementation/Python Implementation/Scripts/scBiGLasso.py:256, in scBiGLasso(N, eps, Ys, beta_1, beta_2, Psi_init, Theta_init, verbose)
#     244 def scBiGLasso(
#     245     N: "Maximum iteration number",
#     246     eps: "Tolerance",
#    (...)
#     252     verbose: bool = False
#     253 ) -> ("Psi", "Theta"):
#     255     T_psi, T_theta = calculate_empirical_covariance_matrices(Ys)
# --> 256     return scBiGLasso_cov(
#     257         N, eps, T_psi, T_theta,
#     258         beta_1, beta_2,
#     259         Psi_init, Theta_init,
#     260         verbose
#     261     )
#
# File ~/Desktop/Python Notebooks.nosync/Research/scBiGLasso Implementation/Python Implementation/Scripts/scBiGLasso.py:212, in scBiGLasso_cov(N, eps, T, S, beta_1, beta_2, Psi_init, Theta_init, verbose)
#     209 Psi, _ = _scBiGLasso_internal(Psi, Theta, T_psi, beta_1, path_Psi, verbose)
#     211 # Now estimate Theta
# --> 212 Theta, log_det = _scBiGLasso_internal(Theta, Psi, T_theta, beta_2, path_Theta, verbose)
#     214 # Keep track of objective function, if verbose
#     215 if verbose:
#
# File ~/Desktop/Python Notebooks.nosync/Research/scBiGLasso Implementation/Python Implementation/Scripts/scBiGLasso.py:131, in _scBiGLasso_internal(Psi, Theta, T, beta, path, verbose)
#     127 # Note that the paper has A @ psi + p * t = 0
#     128 # But sklearn minimizes A @ psi - p * t
#     129 # Hence the factor of -p we apply.
#     130 if beta > 0:
# --> 131     psi_isi_update = LASSO(A_sisi, -p * t_isi, beta)
#     132 else:
#     133     # Warning: this code breaks, there's a bug on this line somewhere
#     134     psi_isi_update = np.linalg.lstsq(A_sisi, p * t_isi, rcond=None)[0]
#
# File ~/Desktop/Python Notebooks.nosync/Research/scBiGLasso Implementation/Python Implementation/Scripts/utilities.py:158, in LASSO(X, y, lmbda, **kwargs)
#     149 def LASSO(
#     150     X: "Coefficient matrix",
#     151     y: "Affine vector",
#     152     lmbda: "L1 penalty",
#     153     **kwargs: "To pass to underlying package"
#     154 ):
#     155     """
#     156     Choose which method of Lasso to use
#     157     """
# --> 158     return LASSO_sklearn(X, y, lmbda, **kwargs)
#
# File ~/Desktop/Python Notebooks.nosync/Research/scBiGLasso Implementation/Python Implementation/Scripts/utilities.py:126, in LASSO_sklearn(X, y, lmbda, **kwargs)
#     124 lasso = linear_model.Lasso(alpha=lmbda, fit_intercept=False, **kwargs)
#     125 try:
# --> 126     return lasso.fit(X, y).coef_
#     127 except ValueError as e:
#     128     print(X)
#
# File ~/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:1039, in ElasticNet.fit(self, X, y, sample_weight, check_input)
#    1037 else:
#    1038     this_Xy = None
# -> 1039 _, this_coef, this_dual_gap, this_iter = self.path(
#    1040     X,
#    1041     y[:, k],
#    1042     l1_ratio=self.l1_ratio,
#    1043     eps=None,
#    1044     n_alphas=None,
#    1045     alphas=[alpha],
#    1046     precompute=precompute,
#    1047     Xy=this_Xy,
#    1048     copy_X=True,
#    1049     verbose=False,
#    1050     tol=self.tol,
#    1051     positive=self.positive,
#    1052     X_offset=X_offset,
#    1053     X_scale=X_scale,
#    1054     return_n_iter=True,
#    1055     coef_init=coef_[k],
#    1056     max_iter=self.max_iter,
#    1057     random_state=self.random_state,
#    1058     selection=self.selection,
#    1059     check_input=False,
#    1060 )
#    1061 coef_[k] = this_coef[:, 0]
#    1062 dual_gaps_[k] = this_dual_gap[0]
#
# File ~/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647, in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     633     model = cd_fast.enet_coordinate_descent_gram(
#     634         coef_,
#     635         l1_reg,
#    (...)
#     644         positive,
#     645     )
#     646 elif precompute is False:
# --> 647     model = cd_fast.enet_coordinate_descent(
#     648         coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
#     649     )
#     650 else:
#     651     raise ValueError(
#     652         "Precompute should be one of True, False, 'auto' or array-like. Got %r"
#     653         % precompute
#     654     )
#
# File sklearn/linear_model/_cd_fast.pyx:251, in sklearn.linear_model._cd_fast.enet_coordinate_descent()
#
# File ~/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/numpy/core/getlimits.py:383, in finfo.__new__(cls, dtype)
#     382 def __new__(cls, dtype):
# --> 383     try:
#     384         dtype = numeric.dtype(dtype)
#     385     except TypeError:
#     386         # In case a float instance was given
#
# KeyboardInterrupt:

# %% [markdown]
# ## anBiGLasso Easy

# %%
# How does choice of betas and matrix size affect results?
# on 'easy' data
# =================== for scBiGLasso ================
samples = [1, 2, 5, 10, 20, 50, 100]
betas = [
    10**np.arange(0, 5, 0.1), # 50
    10**np.arange(0, 5, 0.1),
    10**np.arange(-4, -1, 0.1),
    10**np.arange(-4, -1, 0.1),
    10**np.arange(-4, -1, 0.1),
    10**np.arange(-4, -1, 0.1),
    10**np.arange(-4, -1, 0.1)
]
vary_sizes_experiment = dict({})
for idx, m in enumerate(samples):
    fig, axs, dicts = create_precision_recall_curves(
        betas[idx],
        m,
        50,
        attempts=50
        indices_to_highlight=[],
        alg="anBiGLasso",
        df_scale=2,
        B_approx_iters=10
    )
    fig.savefig(
        f'../Plots/Vary Samples - anBiGLasso - Easy - Approx/Precision-Recall-Vary-Samples-{m}'
    )
    display(fig) # Force figure to display NOW (`fig.show()` does not do this)
    plt.close(fig) # Suppress double-displaying the figure
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/k0/qy74mdx10qs493700g929k5h0000gn/T/ipykernel_4843/392707020.py", line 16, in <cell line: 15>
#     fig, axs, dicts = create_precision_recall_curves(
#   File "/Users/baileyandrew/Desktop/Python Notebooks.nosync/Research/scBiGLasso Implementation/Python Implementation/Scripts/experiments.py", line 178, in create_precision_recall_curves
#     Psi_cms, Theta_cms = get_cms_for_betas(
#   File "/Users/baileyandrew/Desktop/Python Notebooks.nosync/Research/scBiGLasso Implementation/Python Implementation/Scripts/experiments.py", line 56, in get_cms_for_betas
#     Psi, Theta = anBiGLasso(
#   File "/Users/baileyandrew/Desktop/Python Notebooks.nosync/Research/scBiGLasso Implementation/Python Implementation/Scripts/anBiGLasso.py", line 26, in anBiGLasso
#     u, v = eigenvalues_MLE(Ys, U, V, B_approx_iters)
#   File "/Users/baileyandrew/Desktop/Python Notebooks.nosync/Research/scBiGLasso Implementation/Python Implementation/Scripts/anBiGLasso.py", line 190, in eigenvalues_MLE
#     u, v = calculateEigenvalues(Sigmas, B_approx_iters)
#   File "/Users/baileyandrew/Desktop/Python Notebooks.nosync/Research/scBiGLasso Implementation/Python Implementation/Scripts/anBiGLasso.py", line 168, in calculateEigenvalues
#     B_[row, :] = 0
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 1982, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/Users/baileyandrew/opt/anaconda3/envs/my_default_environment/lib/python3.9/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %% [markdown]
# # EiGLasso Easy

# %%
# How does choice of betas and matrix size affect results?
# on 'easy' data
# =================== for scBiGLasso ================
samples = [1, 2, 5, 10, 20, 50, 100]
betas = [
    10**np.arange(-3, 0, 0.1), # 50
    10**np.arange(-3, 0, 0.1),
    10**np.arange(-3, 0, 0.1),
    10**np.arange(-3, 0, 0.1),
    10**np.arange(-3, 0, 0.1),
    10**np.arange(-3, 0, 0.1),
    10**np.arange(-3, 0, 0.1)
]
vary_sizes_experiment = dict({})
for idx, m in enumerate(samples):
    fig, axs, dicts = create_precision_recall_curves(
        betas[idx],
        m,
        50,
        attempts=25,
        indices_to_highlight=[],
        alg="EiGLasso",
        df_scale=2
    )
    fig.savefig(
        f'../Plots/Vary Samples - EiGLasso - Easy/Precision-Recall-Vary-Samples-{m}'
    )
    display(fig) # Force figure to display NOW (`fig.show()` does not do this)
    plt.close(fig) # Suppress double-displaying the figure
