# %%
import sys
sys.path.append('..')

# %%
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler
colorscheme = cycler(color=[
    '#006BA4',
    '#595959',
    '#FF800E',
    '#ABABAB',
    '#5F9ED1',
    '#C85200',
    '#898989',
    '#A2C8EC',
    '#FFBC79',
    '#CFCFCF'
])

# %%
from Scripts.experiments import make_cm_plots_tensor, make_cm_plots_antGLasso
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Runtime Figures

# %%
ahs3ds = np.load(
    f'../../Data for Plots/RUN ant hard small 3D sizes.npy'
)
ths3ds = np.load(
    f'../../Data for Plots/RUN tera hard small 3D sizes.npy'
)
aes3ds = np.load(
    f'../../Data for Plots/RUN ant easy small 3D sizes.npy'
)
tes3ds = np.load(
    f'../../Data for Plots/RUN tera easy small 3D sizes.npy'
)
ahs3d = np.load(
    f'../../Data for Plots/RUN ant hard small 3D.npy'
)
ths3d = np.load(
    f'../../Data for Plots/RUN tera hard small 3D.npy'
)
aes3d = np.load(
    f'../../Data for Plots/RUN ant easy small 3D.npy'
)
tes3d = np.load(
    f'../../Data for Plots/RUN tera easy small 3D.npy'
)

# %%
with plt.style.context('Solarize_Light2'):
        plt.rcParams['axes.prop_cycle'] = colorscheme
        fig1, (ax1, ax2) = plt.subplots(figsize=(16, 8), ncols=2)
        ax1.plot(
            ahs3ds,
            ahs3d,
            label='antGLasso'
        )
        ax1.plot(ths3ds,
                 ths3d,
                 label='TeraLasso'
        )
        ax1.set_xlabel("Size of Precision Matrices")
        ax1.set_ylabel("Seconds")
        ax1.set_title(f"Runtime for small-sample [n*n*n] hard data")
        ax1.set_ylim([0, 60])
        ax1.legend()
        
        ax2.plot(
            aes3ds,
            aes3d,
            label='antGLasso'
        )
        ax2.plot(tes3ds,
                 tes3d,
                 label='TeraLasso'
        )
        ax2.set_xlabel("Size of Precision Matrices")
        ax2.set_ylabel("Seconds")
        ax2.set_title(f"Runtime for small-sample [n*n*n] easy data")
        ax2.set_ylim([0, 60])
        ax2.legend()
        
        fig1.savefig(f'../../Plots/Final/All Together Tensors')

# %%
ahs2ds = np.load(
    f'../../Data for Plots/RUN ant hard small 2D sizes.npy'
)
ths2ds = np.load(
    f'../../Data for Plots/RUN tera hard small 2D sizes.npy'
)
ehs2ds = np.load(
    f'../../Data for Plots/RUN eig hard small 2D sizes.npy'
)
shs2ds = np.load(
    f'../../Data for Plots/RUN sc hard small 2D sizes.npy'
)
aes2ds = np.load(
    f'../../Data for Plots/RUN ant easy small 2D sizes.npy'
)
tes2ds = np.load(
    f'../../Data for Plots/RUN tera easy small 2D sizes.npy'
)
ees2ds = np.load(
    f'../../Data for Plots/RUN eig easy small 2D sizes.npy'
)
ses2ds = np.load(
    f'../../Data for Plots/RUN sc easy small 2D sizes.npy'
)

ahs2d = np.load(
    f'../../Data for Plots/RUN ant hard small 2D.npy'
)
ths2d = np.load(
    f'../../Data for Plots/RUN tera hard small 2D.npy'
)
ehs2d = np.load(
    f'../../Data for Plots/RUN eig hard small 2D.npy'
)
shs2d = np.load(
    f'../../Data for Plots/RUN sc hard small 2D.npy'
)
aes2d = np.load(
    f'../../Data for Plots/RUN ant easy small 2D.npy'
)
tes2d = np.load(
    f'../../Data for Plots/RUN tera easy small 2D.npy'
)
ees2d = np.load(
    f'../../Data for Plots/RUN eig easy small 2D.npy'
)
ses2d = np.load(
    f'../../Data for Plots/RUN sc easy small 2D.npy'
)


ahl2ds = np.load(
    f'../../Data for Plots/RUN ant hard large 2D sizes.npy'
)
thl2ds = np.load(
    f'../../Data for Plots/RUN tera hard large 2D sizes.npy'
)
ehl2ds = np.load(
    f'../../Data for Plots/RUN eig hard large 2D sizes.npy'
)
shl2ds = np.load(
    f'../../Data for Plots/RUN sc hard large 2D sizes.npy'
)
ael2ds = np.load(
    f'../../Data for Plots/RUN ant easy large 2D sizes.npy'
)
tel2ds = np.load(
    f'../../Data for Plots/RUN tera easy large 2D sizes.npy'
)
eel2ds = np.load(
    f'../../Data for Plots/RUN eig easy large 2D sizes.npy'
)
sel2ds = np.load(
    f'../../Data for Plots/RUN sc easy large 2D sizes.npy'
)

ahl2d = np.load(
    f'../../Data for Plots/RUN ant hard large 2D.npy'
)
thl2d = np.load(
    f'../../Data for Plots/RUN tera hard large 2D.npy'
)
ehl2d = np.load(
    f'../../Data for Plots/RUN eig hard large 2D.npy'
)
shl2d = np.load(
    f'../../Data for Plots/RUN sc hard large 2D.npy'
)
ael2d = np.load(
    f'../../Data for Plots/RUN ant easy large 2D.npy'
)
tel2d = np.load(
    f'../../Data for Plots/RUN tera easy large 2D.npy'
)
eel2d = np.load(
    f'../../Data for Plots/RUN eig easy large 2D.npy'
)
sel2d = np.load(
    f'../../Data for Plots/RUN sc easy large 2D.npy'
)

# %%
with plt.style.context('Solarize_Light2'):
        plt.rcParams['axes.prop_cycle'] = colorscheme
        fig1, ((ax1, ax2), (ax3, ax4)) = plt.subplots(figsize=(16, 12), nrows=2, ncols=2)
        ax1.plot(
            ahs2ds,
            ahs2d,
            label='antGLasso'
        )
        ax1.plot(
            ths2ds,
            ths2d,
            label='TeraLasso'
        )
        ax1.plot(
            ehs2ds,
            ehs2d,
            label='EiGLasso'
        )
        ax1.plot(
            shs2ds,
            shs2d,
            label='scBiGLasso'
        )
        ax1.set_xlabel("Size of Precision Matrices (n=p)")
        ax1.set_ylabel("Seconds")
        ax1.set_title(f"Runtime for small-sample hard data")
        ax1.set_ylim([0, 60])
        ax1.legend()
        
        ax2.plot(
            aes2ds,
            aes2d,
            label='antGLasso'
        )
        ax2.plot(
            tes2ds,
            tes2d,
            label='TeraLasso'
        )
        ax2.plot(
            ees2ds,
            ees2d,
            label='EiGLasso'
        )
        ax2.plot(
            ses2ds,
            ses2d,
            label='scBiGLasso'
        )
        ax2.set_xlabel("Size of Precision Matrices (n=p)")
        ax2.set_ylabel("Seconds")
        ax2.set_title(f"Runtime for small-sample easy data")
        ax2.set_ylim([0, 60])
        ax2.legend()
        
        ax3.plot(
            ahl2ds,
            ahl2d,
            label='antGLasso'
        )
        ax3.plot(
            thl2ds,
            thl2d,
            label='TeraLasso'
        )
        ax3.plot(
            ehl2ds,
            ehl2d,
            label='EiGLasso'
        )
        ax3.plot(
            shl2ds,
            shl2d,
            label='scBiGLasso'
        )
        ax3.set_xlabel("Size of Precision Matrices (n=p)")
        ax3.set_ylabel("Seconds")
        ax3.set_title(f"Runtime for large-sample hard data")
        ax3.set_ylim([0, 60])
        ax3.legend()
        
        ax4.plot(
            ael2ds,
            ael2d,
            label='antGLasso'
        )
        ax4.plot(
            tel2ds,
            tel2d,
            label='TeraLasso'
        )
        ax4.plot(
            eel2ds,
            eel2d,
            label='EiGLasso'
        )
        ax4.plot(
            sel2ds,
            sel2d,
            label='scBiGLasso'
        )
        ax4.set_xlabel("Size of Precision Matrices (n=p)")
        ax4.set_ylabel("Seconds")
        ax4.set_title(f"Runtime for large-sample easy data")
        ax4.set_ylim([0, 60])
        ax4.legend()
        
        fig1.savefig(f'../../Plots/Final/All Together')

# %% [markdown]
# # Performance Figures

# %%
pr1_50_50 = np.load('../../Data for Plots/PR 1 of 50x50.npy')
fig, _ = make_cm_plots_tensor(
    Psis_cms=pr1_50_50,
    algorithms=[
        "antGLasso",
        "TeraLasso",
        #"scBiGLasso",
        "EiGLasso",
        "anBiGLasso_cov"
    ],
    title = None
)
fig.savefig(f'../../Plots/Final/PR 1 of 50x50', bbox_inches='tight')

# %%
pr10_50_50 = np.load('../../Data for Plots/PR 10 of 50x50.npy')
fig, _ = make_cm_plots_tensor(
    Psis_cms=pr10_50_50,
    algorithms=[
        "antGLasso",
        "TeraLasso",
        "scBiGLasso",
        "EiGLasso",
        "anBiGLasso_cov"
    ],
    title = None
)
fig.savefig(f'../../Plots/Final/PR 10 of 50x50', bbox_inches='tight')

# %%
pr100_50_50 = np.load('../../Data for Plots/PR 100 of 50x50.npy')
fig, ax = make_cm_plots_tensor(
    Psis_cms=pr100_50_50,
    algorithms=[
        "antGLasso",
        "TeraLasso",
        "scBiGLasso",
        "EiGLasso",
        "anBiGLasso_cov"
    ],
    title = None
)
fig.savefig(f'../../Plots/Final/PR 100 of 50x50', bbox_inches='tight')

# %%
pr10_50_50_50 = np.load('../../Data for Plots/PR 10 of 50x50x50.npy')
fig, ax = make_cm_plots_tensor(
    Psis_cms=pr10_50_50_50,
    algorithms=[
        "antGLasso",
        "TeraLasso"
    ],
    title = None
)
fig.savefig(f'../../Plots/Final/PR 10 of 50x50x50', bbox_inches='tight')

# %%
pr100_50_50_50 = np.load('../../Data for Plots/PR 100 of 50x50x50.npy')
fig, ax = make_cm_plots_tensor(
    Psis_cms=pr100_50_50_50,
    algorithms=[
        "antGLasso",
        "TeraLasso"
    ],
    title = None
)
fig.savefig(f'../../Plots/Final/PR 100 of 50x50x50', bbox_inches='tight')

# %%
compare_sizes = np.load('../../Data for Plots/PR antGLasso vary sizes.npy')
fig, ax = make_cm_plots_antGLasso(
    Psis_cms=compare_sizes,
    sizes=[(10, 10), (50, 50), (100, 100), (500, 500)],
    samples=[50]
)
fig.savefig(f'../../Plots/Final/PR antGLasso vary sizes', bbox_inches='tight')

# %%
compare_samples = np.load('../../Data for Plots/PR antGLasso vary samples.npy')
fig, ax = make_cm_plots_antGLasso(
    Psis_cms=compare_samples,
    sizes=[(50, 50)],
    samples=[1, 10, 50, 100, 250, 1000]
)
fig.savefig(f'../../Plots/Final/PR antGLasso vary samples', bbox_inches='tight')

# %% [markdown]
# # Sparsity-Estimation Regularization

# %%
sbr = np.load('../../Data for Plots/PR antGLasso sparsity-based regularization.npy')
fig, ax = make_cm_plots_antGLasso(
    Psis_cms=sbr,
    sizes=[(100, 100)],
    samples=[100],
    betas_to_highlight=[[0, 2, 4, 8, 16]],
    betas=np.array([
        np.arange(0., 1, 0.05), #Size 100 Sample 100
    ])
)
fig.savefig(f'../../Plots/Final/PR antGLasso sparsity-based regularization', bbox_inches='tight')

# %%
sbr = np.load('../../Data for Plots/PR antGLasso sparsity-based regularization 10pc.npy')
fig, ax = make_cm_plots_antGLasso(
    Psis_cms=sbr,
    sizes=[(100, 100)],
    samples=[100],
    betas_to_highlight=[[0, 2, 4, 8, 16]],
    betas=np.array([
        np.arange(0., 1, 0.05), #Size 100 Sample 100
    ])
)
fig.savefig(
    f'../../Plots/Final/PR antGLasso sparsity-based regularization 10pc',
    bbox_inches='tight'
)

# %%
sbr = np.load('../../Data for Plots/PR antGLasso sparsity-based regularization 40pc.npy')
fig, ax = make_cm_plots_antGLasso(
    Psis_cms=sbr,
    sizes=[(100, 100)],
    samples=[100],
    betas_to_highlight=[[0, 2, 4, 8, 16]],
    betas=np.array([
        np.arange(0., 1, 0.05), #Size 100 Sample 100
    ])
)
fig.savefig(
    f'../../Plots/Final/PR antGLasso sparsity-based regularization 40pc',
    bbox_inches='tight'
)

# %% [markdown]
# # Real World Data
