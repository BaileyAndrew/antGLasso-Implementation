# %%
import dependencies
import soft_dependencies
# Out:
# Python Version 3.9.12 (main, Apr  5 2022, 01:53:17)
# [Clang 12.0.0 ]
# Numpy Version 1.21.5
# Scipy Version 1.7.3
# Sklearn Version 1.0.2
# Matplotlib Version 3.5.1
# Pandas Version 1.4.2
# Line Profiler Version 3.3.1
# Memory Profiler Version 0.58.0

# %%
import numpy as np
import matplotlib.pyplot as plt

np.set_printoptions(precision=3, suppress=True)
# %load_ext autoreload
# %autoreload 2

# %%
from Scripts.experiments import create_precision_recall_curves

# %% [markdown]
# # scBiGLasso Easy Data

# %%
# How does choice of betas and matrix size affect results?
# on 'easy' data
# =================== for scBiGLasso ================
sizes = [20, 40, 60, 80, 100]
betas = [
    10**np.arange(-2, 0, 0.05), # 20
    10**np.arange(-2, 0, 0.05), # 40
    10**np.arange(-1, 1, 0.05), # 60
    10**np.arange(-1, 1, 0.1), # 80
    10**np.arange(-1, 1, 0.1) # 100
]
interesting_indices = [
    [2, 16, 24],
    [2, 16, 24],
    [2, 12, 16],
    [2, 6, 10],
    [2, 6, 10, 14]
]
vary_sizes_experiment = dict({})
for idx, size in enumerate(sizes):
    fig, axs, dicts = create_precision_recall_curves(
        betas[idx],
        100,
        size,
        attempts=25,
        indices_to_highlight=interesting_indices[idx],
        alg="scBiGLasso",
        df_scale=2
    )
    vary_sizes_experiment[size] = dicts
    fig.savefig(f'../Plots/Vary Sizes - scBiGLasso - Easy/Precision-Recall-Vary-Sizes-{size}')
    display(fig) # Force figure to display NOW (`fig.show()` does not do this)
    plt.close(fig) # Suppress double-displaying the figure
#np.save('../Data/Vary-Sizes-Experiment/Precisions-and-Recalls.npy', vary_sizes_experiment) 
    
# Obeservation: the larger the size, the more 'stable' the results are, as in
# the precision-recall curve is smoother

# %% [markdown]
# # anBiGLasso Easy Data

# %% [markdown]
# ## Full B

# %%
# How does choice of betas and matrix size affect results?
# on 'easy' data
# =================== for anBiGLasso ================
sizes = [40, 60, 80, 100]#, 120] # 120 takes too much memory for me
betas = [
    10**np.arange(-4, -1, 0.05), # 40
    10**np.arange(-4, -1, 0.05), # 60
    10**np.arange(-5, -2, 0.05), # 80
    10**np.arange(-5, -2, 0.05), # 100
    10**np.arange(-5, -2, 0.05), # 120
]
interesting_indices = [
    [2, 16, 24],
    [2, 16, 24],
    [2, 16, 24],
    [2, 16, 24],
    [2, 16, 24]
]
#vary_sizes_experiment = dict({})
for idx, size in enumerate(sizes):
    fig, axs, dicts = create_precision_recall_curves(
        betas[idx],
        100,
        size,
        attempts=25,
        indices_to_highlight=interesting_indices[idx],
        alg="anBiGLasso",
        df_scale=2,
        B_approx_iters=-1
    )
    #vary_sizes_experiment[size] = dicts
    fig.savefig(f'../Plots/Vary Sizes - anBiGLasso - Easy/Precision-Recall-Vary-Sizes-{size}')
    display(fig) # Force figure to display NOW (`fig.show()` does not do this)
    plt.close(fig) # Suppress double-displaying the figure
#np.save('../Data/Vary-Sizes-Experiment/Precisions-and-Recalls.npy', vary_sizes_experiment)

# %% [markdown]
# ## Approximate B

# %%
# How does choice of betas and matrix size affect results?
# on 'easy' data
# =================== for anBiGLasso ================
sizes = [40, 60, 80, 100]#, 120] # 120 takes too much memory for me
betas = [
    10**np.arange(-4, -1, 0.05), # 40
    10**np.arange(-4, -1, 0.05), # 60
    10**np.arange(-5, -2, 0.05), # 80
    10**np.arange(-5, -2, 0.05), # 100
    10**np.arange(-5, -2, 0.05), # 120
]
interesting_indices = [
    [2, 16, 24],
    [2, 16, 24],
    [2, 16, 24],
    [2, 16, 24],
    [2, 16, 24]
]
#vary_sizes_experiment = dict({})
for idx, size in enumerate(sizes):
    fig, axs, dicts = create_precision_recall_curves(
        betas[idx],
        100,
        size,
        attempts=25,
        indices_to_highlight=interesting_indices[idx],
        alg="anBiGLasso",
        df_scale=2,
        B_approx_iters=10
    )
    #vary_sizes_experiment[size] = dicts
    fig.savefig(
        f'../Plots/Vary Sizes - anBiGLasso - Easy - Approx/'
        + f'Precision-Recall-Vary-Sizes-{size}')
    display(fig) # Force figure to display NOW (`fig.show()` does not do this)
    plt.close(fig) # Suppress double-displaying the figure
#np.save('../Data/Vary-Sizes-Experiment/Precisions-and-Recalls.npy', vary_sizes_experiment)

# %% [markdown]
# # EiGLasso Easy Data

# %%
# How does choice of betas and matrix size affect results?
# on 'easy' data
# =================== for scBiGLasso ================
sizes = [20, 40, 60, 80, 100]
betas = [
    10**np.arange(-3, -1, 0.05), # 20
    10**np.arange(-3, -1, 0.05), # 40
    10**np.arange(-3, -1, 0.05), # 60
    10**np.arange(-3, -1, 0.1), # 80
    10**np.arange(-3, -1, 0.1) # 100
]
interesting_indices = [
    [2, 16, 24],
    [2, 16, 24],
    [2, 12, 16],
    [2, 6, 10],
    [2, 6, 10, 14]
]
vary_sizes_experiment = dict({})
for idx, size in enumerate(sizes):
    fig, axs, dicts = create_precision_recall_curves(
        betas[idx],
        100,
        size,
        attempts=25,
        indices_to_highlight=interesting_indices[idx],
        alg="EiGLasso",
        df_scale=2
    )
    vary_sizes_experiment[size] = dicts
    fig.savefig(f'../Plots/Vary Sizes - EiGLasso - Easy/Precision-Recall-Vary-Sizes-{size}')
    display(fig) # Force figure to display NOW (`fig.show()` does not do this)
    plt.close(fig) # Suppress double-displaying the figure
#np.save('../Data/Vary-Sizes-Experiment/Precisions-and-Recalls.npy', vary_sizes_experiment) 
    
# Obeservation: the larger the size, the more 'stable' the results are, as in
# the precision-recall curve is smoother

# %% [markdown]
# # scBiGLasso Hard Data

# %%
# How does choice of betas and matrix size affect results?
# on 'hard' data
# =================== for scBiGLasso ================
sizes = [20, 40]
betas = [
    10**np.arange(-2, 0, 0.05), # 20
    10**np.arange(-2, 0, 0.05), # 40
    10**np.arange(-1, 1, 0.05), # 60
    10**np.arange(-1, 1, 0.1), # 80
    10**np.arange(-1, 1, 0.1) # 100
]
interesting_indices = [
    [2, 16, 24],
    [2, 16, 24],
    [2, 12, 16],
    [2, 6, 10],
    [2, 6, 10, 14]
]
vary_sizes_experiment = dict({})
for idx, size in enumerate(sizes):
    fig, axs, dicts = create_precision_recall_curves(
        betas[idx],
        100,
        size,
        attempts=25,
        indices_to_highlight=interesting_indices[idx],
        alg="scBiGLasso",
        df_scale=1
    )
    vary_sizes_experiment[size] = dicts
    fig.savefig(f'../Plots/Vary Sizes - scBiGLasso - Hard/Precision-Recall-Vary-Sizes-{size}')
    display(fig) # Force figure to display NOW (`fig.show()` does not do this)
    plt.close(fig) # Suppress double-displaying the figure
#np.save('../Data/Vary-Sizes-Experiment/Precisions-and-Recalls.npy', vary_sizes_experiment) 
    
# Obeservation: the larger the size, the more 'stable' the results are, as in
# the precision-recall curve is smoother

# %% [markdown]
# # anBiGLasso Hard Data

# %% [markdown]
# ## Full B

# %%
# How does choice of betas and matrix size affect results?
# on 'hard' data
# =================== for anBiGLasso ================
sizes = [40, 60, 80, 100]#, 120]
betas = [
    10**np.arange(-4, -1, 0.05), # 40
    10**np.arange(-4, -1, 0.05), # 60
    10**np.arange(-5, -2, 0.05), # 80
    10**np.arange(-5, -2, 0.05), # 100
    10**np.arange(-5, -2, 0.05), # 120
]
interesting_indices = [
    [2, 16, 24],
    [2, 16, 24],
    [2, 16, 24],
    [2, 16, 24],
    [2, 16, 24]
]
#vary_sizes_experiment = dict({})
for idx, size in enumerate(sizes):
    fig, axs, dicts = create_precision_recall_curves(
        betas[idx],
        100,
        size,
        attempts=25,
        indices_to_highlight=interesting_indices[idx],
        alg="anBiGLasso",
        df_scale=1,
        B_approx_iters=-1
    )
    #vary_sizes_experiment[size] = dicts
    fig.savefig(f'../Plots/Vary Sizes - anBiGLasso - Hard/Precision-Recall-Vary-Sizes-{size}')
    display(fig) # Force figure to display NOW (`fig.show()` does not do this)
    plt.close(fig) # Suppress double-displaying the figure
#np.save('../Data/Vary-Sizes-Experiment/Precisions-and-Recalls.npy', vary_sizes_experiment) 

# If we generate data from invwishart with the degrees-of-freedom parameter equal
# to the size of the data, results are worse than if the degrees-of-freedom is larger.
# Currently its set to do the worst.
# (Well, I don't think the alg actually does worse on average, it just has a
# notably higher variance.)

# %% [markdown]
# ## Approximate B

# %%
# How does choice of betas and matrix size affect results?
# on 'hard' data
# =================== for anBiGLasso ================
sizes = [40, 60, 80, 100]#, 120]
betas = [
    10**np.arange(-4, -1, 0.05), # 40
    10**np.arange(-4, -1, 0.05), # 60
    10**np.arange(-5, -2, 0.05), # 80
    10**np.arange(-5, -2, 0.05), # 100
    10**np.arange(-5, -2, 0.05), # 120
]
interesting_indices = [
    [2, 16, 24],
    [2, 16, 24],
    [2, 16, 24],
    [2, 16, 24],
    [2, 16, 24]
]
#vary_sizes_experiment = dict({})
for idx, size in enumerate(sizes):
    fig, axs, dicts = create_precision_recall_curves(
        betas[idx],
        100,
        size,
        attempts=25,
        indices_to_highlight=interesting_indices[idx],
        alg="anBiGLasso",
        df_scale=1,
        B_approx_iters=10
    )
    #vary_sizes_experiment[size] = dicts
    fig.savefig(
        f'../Plots/Vary Sizes - anBiGLasso - Hard - Approx/'
        + f'Precision-Recall-Vary-Sizes-{size}'
    )
    display(fig) # Force figure to display NOW (`fig.show()` does not do this)
    plt.close(fig) # Suppress double-displaying the figure
#np.save('../Data/Vary-Sizes-Experiment/Precisions-and-Recalls.npy', vary_sizes_experiment) 

# If we generate data from invwishart with the degrees-of-freedom parameter equal
# to the size of the data, results are worse than if the degrees-of-freedom is larger.
# Currently its set to do the worst.
# (Well, I don't think the alg actually does worse on average, it just has a
# notably higher variance.)

# %% [markdown]
# # EiGLasso - Hard Data

# %%
# How does choice of betas and matrix size affect results?
# on 'easy' data
# =================== for scBiGLasso ================
sizes = [20, 40, 60, 80, 100]
betas = [
    10**np.arange(-3, -1, 0.05), # 20
    10**np.arange(-3, -1, 0.05), # 40
    10**np.arange(-3, -1, 0.05), # 60
    10**np.arange(-3, -1, 0.1), # 80
    10**np.arange(-3, -1, 0.1) # 100
]
interesting_indices = [
    [2, 16, 24],
    [2, 16, 24],
    [2, 12, 16],
    [2, 6, 10],
    [2, 6, 10, 14]
]
vary_sizes_experiment = dict({})
for idx, size in enumerate(sizes):
    fig, axs, dicts = create_precision_recall_curves(
        betas[idx],
        100,
        size,
        attempts=25,
        indices_to_highlight=interesting_indices[idx],
        alg="EiGLasso",
        df_scale=1
    )
    vary_sizes_experiment[size] = dicts
    fig.savefig(f'../Plots/Vary Sizes - EiGLasso - Hard/Precision-Recall-Vary-Sizes-{size}')
    display(fig) # Force figure to display NOW (`fig.show()` does not do this)
    plt.close(fig) # Suppress double-displaying the figure
#np.save('../Data/Vary-Sizes-Experiment/Precisions-and-Recalls.npy', vary_sizes_experiment) 
    
# Obeservation: the larger the size, the more 'stable' the results are, as in
# the precision-recall curve is smoother
